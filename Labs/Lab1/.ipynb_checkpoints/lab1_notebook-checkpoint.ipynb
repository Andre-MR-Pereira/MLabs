# %%
import numpy as np
import matplotlib.pyplot as plt
from lab1 import poly_fit, poly, poly_vector,compute_SSE,indic

# %%
x = np.load('./data1_x.npy')
y = np.load('./data1_y.npy')

# %%
a = poly_fit(x,y,2)

x_ = np.linspace(-1, 1, 101)
y_ = poly_vector(a, x_)

plt.scatter(x,y)
plt.plot(x_,y_)
plt.show()

indic(y,x,a)
# Out:
# B coeficients are:
# [0.63512224]
# [1.7332128]
#
#
# SSE is:
# 0.7433354116956701

# %%
x = np.load('./data2_x.npy')
y = np.load('./data2_y.npy')

a = poly_fit(x,y,3)

x_ = np.linspace(-1, 1, 101)
y_ = poly_vector(a, x_)

plt.scatter(x,y)
plt.plot(x_,y_)
plt.show()

indic(y,x,a)

# %%
x = np.load('./data2a_x.npy')
y = np.load('./data2a_y.npy')

a = poly_fit(x,y,3)

x_ = np.linspace(-1, 1, 101)
y_ = poly_vector(a, x_)

plt.scatter(x,y)
plt.plot(x_,y_)
plt.show()

indic(y,x,a)
