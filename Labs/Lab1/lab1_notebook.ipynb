# %%
import numpy as np
import matplotlib.pyplot as plt
from lab1 import poly_fit, poly

# %%
x = np.load('./data_lab1/data1_x.npy')
y = np.load('./data_lab1/data1_y.npy')

# %%
a = poly_fit(x,y,2)

x_ = np.linspace(-1, 1, 101)
y_ = np.zeros([len(x_)])

for i in range(0, len(x_)):
    y_[i] = poly(a, x_[i])
    
plt.scatter(x,y)
plt.plot(x_,y_)
plt.show()
