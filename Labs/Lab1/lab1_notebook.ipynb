# %%
import numpy as np
import matplotlib.pyplot as plt
from lab1 import poly_fit, poly, poly_vector

# %%
x = np.load('./data1_x.npy')
y = np.load('./data1_y.npy')

# %%
a = poly_fit(x,y,2)

x_ = np.linspace(-1, 1, 101)
y_ = poly_vector(a, x_)

plt.scatter(x,y)
plt.plot(x_,y_)
plt.show()

# %%
x = np.load('./data2_x.npy')
y = np.load('./data2_y.npy')

a = poly_fit(x,y,3)

x_ = np.linspace(-1, 1, 101)
y_ = poly_vector(a, x_)

plt.scatter(x,y)
plt.plot(x_,y_)
plt.show()

# %%
x = np.load('./data2a_x.npy')
y = np.load('./data2a_y.npy')

a = poly_fit(x,y,3)

x_ = np.linspace(-1, 1, 101)
y_ = poly_vector(a, x_)

plt.scatter(x,y)
plt.plot(x_,y_)
plt.show()
